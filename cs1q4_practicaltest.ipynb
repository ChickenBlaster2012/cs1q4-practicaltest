# %% [markdown]
# <a href="https://colab.research.google.com/github/ChickenBlaster2012/cs1q4-practicaltest/blob/main/cs1q4_practicaltest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("What is your name? ")
print("Hello " + name + "!")

number = input("How many quiz scores do you have? ")
number = int(number)

scores = []
print("Please enter your scores out of 100:")

for i in range(number):
    score = input("Enter score: ")
    scores.append(float(score))

def calculate_results():
    total = sum(scores)
    average = total / number
    average = round(average, 2)

    print("Done! Here are your results:")
    print("Total Score: " + str(total))
    print("Average Score: " + str(average))

    if average >= 75:
        print("Result: PASSED")
    else:
        print("Result: FAILED")

calculate_results()
# Out:
# What is your name? khyce
# Hello khyce!
# How many quiz scores do you have? 2
# Please enter your scores out of 100:
# Enter score: 97
# Enter score: 9
# Done! Here are your results:
# Total Score: 106.0
# Average Score: 53.0
# Result: FAILED
